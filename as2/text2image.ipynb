# %% [markdown]
# <div style="text-align: right">   </div>
#
#
# Introduction to Deep Learning (2023) &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;| &nbsp;
# -------|-------------------
# **Assignment 2 - Recurrent Neural Networks** | <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/UniversiteitLeidenLogo.svg/1280px-UniversiteitLeidenLogo.svg.png" width="300">
#
#
#
# # Introduction
#
#
# The goal of this assignment is to learn how to use encoder-decoder recurrent neural networks (RNNs). Specifically we will be dealing with a sequence to sequence problem and try to build recurrent models that can learn the principles behind simple arithmetic operations (**integer addition, subtraction and multiplication.**).
#
# <img src="https://i.ibb.co/5Ky5pbk/Screenshot-2023-11-10-at-07-51-21.png" alt="Screenshot-2023-11-10-at-07-51-21" border="0" width="500"></a>
#
# In this assignment you will be working with three different kinds of models, based on input/output data modalities:
# 1. **Text-to-text**: given a text query containing two integers and an operand between them (+ or -) the model's output should be a sequence of integers that match the actual arithmetic result of this operation
# 2. **Image-to-text**: same as above, except the query is specified as a sequence of images containing individual digits and an operand.
# 3. **Text-to-image**: the query is specified in text format as in the text-to-text model, however the model's output should be a sequence of images corresponding to the correct result.
#
#
# ### Description**
# Let us suppose that we want to develop a neural network that learns how to add or subtract
# two integers that are at most two digits long. For example, given input strings of 5 characters: ‘81+24’ or
# ’41-89’ that consist of 2 two-digit long integers and an operand between them, the network should return a
# sequence of 3 characters: ‘105 ’ or ’-48 ’ that represent the result of their respective queries. Additionally,
# we want to build a model that generalizes well - if the network can extract the underlying principles behind
# the ’+’ and ’-’ operands and associated operations, it should not need too many training examples to generate
# valid answers to unseen queries. To represent such queries we need 13 unique characters: 10 for digits (0-9),
# 2 for the ’+’ and ’-’ operands and one for whitespaces ’ ’ used as padding.
# The example above describes a text-to-text sequence mapping scenario. However, we can also use different
# modalities of data to represent our queries or answers. For that purpose, the MNIST handwritten digit
# dataset is going to be used again, however in a slightly different format. The functions below will be used to create our datasets.
#
# ---
#
# *To work on this notebook you should create a copy of it.*

# %% [markdown]
# # Function definitions for creating the datasets
#
# First we need to create our datasets that are going to be used for training our models.
#
# In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library. We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
import random
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, RNN, LSTM, Flatten, TimeDistributed, LSTMCell
from tensorflow.keras.layers import RepeatVector, Conv2D, SimpleRNN, GRU, Reshape, ConvLSTM2D, Conv2DTranspose
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, RepeatVector, TimeDistributed, Dense, Reshape, Bidirectional, Dropout, BatchNormalization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from scipy.ndimage import rotate
# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):

    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images

def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:

    @return:
    X_text: '151+ 21' -> text query of an arithmetic operation (7 )
    X_img : Stack of MNIST images corresponding to the query (7 x 28 x 28) -> sequence of 7 images of size 28x28
    y_text: ' 172' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (4 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            # for k in range(highest_integer + 1):  # Third addend
                # i_char = to_padded_chars(i, max_len=max_int_length) # convert integers to strings of constant length [20->' 20']
                # j_char = to_padded_chars(j, max_len=max_int_length, pad_right=True)
                # k_char = to_padded_chars(k, max_len=max_int_length, pad_right=True)

            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []
                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())

                X_text.append(query_string)
                X_img.append(np.stack(query_image))
                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '
    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
# # Creating our data
#
# The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#   **X_text**: strings containing queries of length 7: ['  1+1  ', '11-18', ...]
#
#   **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#   **y_text**: strings containing answers of length 3: ['  2', '156']
#
#   **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)


## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #9365
#
# X_text: "46-82" = y_text: "-36"
# ==================================================
# Query #4440
#
# X_text: "22+20" = y_text: "42 "
# ==================================================
# Query #8289
#
# X_text: "41-44" = y_text: "-3 "
# ==================================================
# Query #4120
#
# X_text: "20+60" = y_text: "80 "
# ==================================================
# Query #9598
#
# X_text: "47+99" = y_text: "146"
# ==================================================
# Query #7883
#
# X_text: "39-41" = y_text: "-2 "
# ==================================================
# Query #8308
#
# X_text: "41+54" = y_text: "95 "
# ==================================================
# Query #5919
#
# X_text: "29-59" = y_text: "-30"
# ==================================================
# Query #996
#
# X_text: "4+98 " = y_text: "102"
# ==================================================
# Query #574
#
# X_text: "2+87 " = y_text: "89 "

# %% [markdown]
# ## Helper functions
#
# The functions below will help with input/output of the data.

# %%
# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs
# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
  n = len(labels)
  length = len(labels[0])
  char_map = dict(zip(unique_characters, range(len(unique_characters))))
  one_hot = np.zeros([n, length, len(unique_characters)])
  for i, label in enumerate(labels):
      m = np.zeros([length, len(unique_characters)])
      for j, char in enumerate(label):
          m[j, char_map[char]] = 1
      one_hot[i] = m

  return one_hot


def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])

    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
# ---
# ---
#
# ## I. Text-to-text RNN model
#
# The following code showcases how Recurrent Neural Networks (RNNs) are built using Keras. Several new layers are going to be used:
#
# 1. LSTM
# 2. TimeDistributed
# 3. RepeatVector
#
# The code cell below explains each of these new components.
#
# <img src="https://i.ibb.co/NY7FFTc/Screenshot-2023-11-10-at-09-27-25.png" alt="Screenshot-2023-11-10-at-09-27-25" border="0" width="500"></a>

# %%
def build_text2text_model():

    # We start by initializing a sequential model
    text2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. Each of these 5 elements in the query will be fed to the network one by one,
    # as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True))

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

# %%
## Your code (look at the assignment description for your tasks for text-to-text model):

# %% [markdown]
# ---
# ---
#
# ## II. Image to text RNN Model
#
# Hint: There are two ways of building the encoder for such a model - again by using the regular LSTM cells (with flattened images as vectors) or recurrect convolutional layers [ConvLSTM2D](https://keras.io/api/layers/recurrent_layers/conv_lstm2d/).
#
# The goal here is to use **X_img** as inputs and **y_text** as outputs.

# %% [markdown]
# ---
# ---
#
# ## III. Text to image RNN Model
#
# Hint: to make this model work really well you could use deconvolutional layers in your decoder (you might need to look up ***Conv2DTranspose*** layer). However, regular vector-based decoder will work as well.
#
# The goal here is to use **X_text** as inputs and **y_img** as outputs.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, RepeatVector, TimeDistributed, Dense, Reshape, Conv2DTranspose
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2DTranspose, BatchNormalization

# %% [markdown]
# # Base model

# %%
def build_text2image_model2():
    text2image = Sequential()

    # Encoder - text
    text2image.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # Repeat the
    text2image.add(RepeatVector(max_answer_length))

    # Decoder - image
    text2image.add(LSTM(256, return_sequences=True))
    text2image.add(TimeDistributed(Dense(128, activation='relu')))
    text2image.add(TimeDistributed(Dense(28 * 28, activation='sigmoid')))
    text2image.add(Reshape((max_answer_length, 28, 28, 1)))


    # Compile the model
    text2image.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

    text2image.summary()

    return text2image   # return the model

# %%
# Prepare the data

parts = [0.8, 0.5]
# Iterate over each split ratio
for part in parts:

    # Split the data into training and test sets
    # The test set size is determined by subtracting the split ratio from 1
    X_text_train, X_text_test, X_img_train, X_img_test, y_text_train, y_text_test, y_img_train, y_img_test = train_test_split(
        X_text, X_img, y_text, y_img, test_size=1 - part, random_state=69
    )

    # Encode the training set
    # The encode_labels function is used to convert the labels into a one-hot encoded format
    X_text_train_onehot = encode_labels(X_text_train)
    y_text_train_onehot = encode_labels(y_text_train)

    # Encode the test set
    # The same encode_labels function is used to convert the labels into a one-hot encoded format
    X_text_test_onehot = encode_labels(X_text_test)
    y_text_test_onehot = encode_labels(y_text_test)

# ----------------------
# Illustrate the generated query/answer pairs (from above create_data)
unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img  = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)
# ---------------------
# Split for visualization
X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_img, train_size=(0.1))

# %%
# Compile the model
text2image_model2 = build_text2image_model2()

# Training the text-to-image model
text2image_model2.fit(
    X_text_train_onehot,
    y_img_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2
)

# Evaluating the model on the test set
test_loss, test_accuracy = text2image_model2.evaluate(
    X_text_test_onehot,
    y_img_test,
)
print(f"Test: {test_accuracy}")
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               276480
#
#  repeat_vector (RepeatVecto  (None, 3, 256)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed (TimeDist  (None, 3, 128)            32896
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 3, 784)            101136
#  stributed)
#
#  reshape (Reshape)           (None, 3, 28, 28, 1)      0
#
# =================================================================
# Total params: 935824 (3.57 MB)
# Trainable params: 935824 (3.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 125/125 [==============================] - 12s 18ms/step - loss: 0.0859 - accuracy: 0.8515 - val_loss: 0.0550 - val_accuracy: 0.8665
# Epoch 2/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0546 - accuracy: 0.8656 - val_loss: 0.0541 - val_accuracy: 0.8660
# Epoch 3/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0544 - accuracy: 0.8652 - val_loss: 0.0540 - val_accuracy: 0.8654
# Epoch 4/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0543 - accuracy: 0.8651 - val_loss: 0.0538 - val_accuracy: 0.8655
# Epoch 5/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0539 - accuracy: 0.8647 - val_loss: 0.0535 - val_accuracy: 0.8660
# Epoch 6/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0535 - accuracy: 0.8646 - val_loss: 0.0530 - val_accuracy: 0.8649
# Epoch 7/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0528 - accuracy: 0.8649 - val_loss: 0.0517 - val_accuracy: 0.8655
# Epoch 8/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0507 - accuracy: 0.8648 - val_loss: 0.0491 - val_accuracy: 0.8651
# Epoch 9/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0489 - accuracy: 0.8644 - val_loss: 0.0483 - val_accuracy: 0.8658
# Epoch 10/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0482 - accuracy: 0.8643 - val_loss: 0.0481 - val_accuracy: 0.8629
# Epoch 11/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0479 - accuracy: 0.8641 - val_loss: 0.0478 - val_accuracy: 0.8639
# Epoch 12/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0477 - accuracy: 0.8640 - val_loss: 0.0473 - val_accuracy: 0.8651
# Epoch 13/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0475 - accuracy: 0.8637 - val_loss: 0.0475 - val_accuracy: 0.8623
# Epoch 14/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0473 - accuracy: 0.8634 - val_loss: 0.0474 - val_accuracy: 0.8645
# Epoch 15/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0471 - accuracy: 0.8633 - val_loss: 0.0469 - val_accuracy: 0.8643
# Epoch 16/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0469 - accuracy: 0.8632 - val_loss: 0.0466 - val_accuracy: 0.8650
# Epoch 17/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0469 - accuracy: 0.8630 - val_loss: 0.0467 - val_accuracy: 0.8621
# Epoch 18/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0467 - accuracy: 0.8628 - val_loss: 0.0467 - val_accuracy: 0.8634
# Epoch 19/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0466 - accuracy: 0.8627 - val_loss: 0.0464 - val_accuracy: 0.8635
# Epoch 20/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0465 - accuracy: 0.8626 - val_loss: 0.0463 - val_accuracy: 0.8638
# Epoch 21/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0465 - accuracy: 0.8626 - val_loss: 0.0466 - val_accuracy: 0.8626
# Epoch 22/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0463 - accuracy: 0.8625 - val_loss: 0.0462 - val_accuracy: 0.8631
# Epoch 23/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0462 - accuracy: 0.8626 - val_loss: 0.0462 - val_accuracy: 0.8611
# Epoch 24/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0461 - accuracy: 0.8624 - val_loss: 0.0463 - val_accuracy: 0.8628
# Epoch 25/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0461 - accuracy: 0.8624 - val_loss: 0.0462 - val_accuracy: 0.8613
# Epoch 26/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0459 - accuracy: 0.8623 - val_loss: 0.0460 - val_accuracy: 0.8630
# Epoch 27/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0459 - accuracy: 0.8622 - val_loss: 0.0457 - val_accuracy: 0.8607
# Epoch 28/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0458 - accuracy: 0.8620 - val_loss: 0.0457 - val_accuracy: 0.8626
# Epoch 29/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0456 - accuracy: 0.8621 - val_loss: 0.0461 - val_accuracy: 0.8619
# Epoch 30/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0456 - accuracy: 0.8619 - val_loss: 0.0456 - val_accuracy: 0.8633
# Epoch 31/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0456 - accuracy: 0.8618 - val_loss: 0.0456 - val_accuracy: 0.8628
# Epoch 32/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0455 - accuracy: 0.8619 - val_loss: 0.0454 - val_accuracy: 0.8617
# Epoch 33/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0453 - accuracy: 0.8616 - val_loss: 0.0453 - val_accuracy: 0.8605
# Epoch 34/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0454 - accuracy: 0.8617 - val_loss: 0.0452 - val_accuracy: 0.8600
# Epoch 35/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0453 - accuracy: 0.8615 - val_loss: 0.0453 - val_accuracy: 0.8611
# Epoch 36/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0452 - accuracy: 0.8616 - val_loss: 0.0451 - val_accuracy: 0.8621
# Epoch 37/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0452 - accuracy: 0.8615 - val_loss: 0.0452 - val_accuracy: 0.8625
# Epoch 38/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0451 - accuracy: 0.8614 - val_loss: 0.0454 - val_accuracy: 0.8602
# Epoch 39/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0450 - accuracy: 0.8614 - val_loss: 0.0452 - val_accuracy: 0.8633
# Epoch 40/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0449 - accuracy: 0.8615 - val_loss: 0.0451 - val_accuracy: 0.8606
# Epoch 41/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0449 - accuracy: 0.8613 - val_loss: 0.0450 - val_accuracy: 0.8614
# Epoch 42/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0448 - accuracy: 0.8613 - val_loss: 0.0452 - val_accuracy: 0.8610
# Epoch 43/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0448 - accuracy: 0.8613 - val_loss: 0.0449 - val_accuracy: 0.8619
# Epoch 44/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0447 - accuracy: 0.8612 - val_loss: 0.0448 - val_accuracy: 0.8608
# Epoch 45/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0446 - accuracy: 0.8613 - val_loss: 0.0447 - val_accuracy: 0.8620
# Epoch 46/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0447 - accuracy: 0.8612 - val_loss: 0.0451 - val_accuracy: 0.8618
# Epoch 47/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0446 - accuracy: 0.8613 - val_loss: 0.0446 - val_accuracy: 0.8611
# Epoch 48/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0445 - accuracy: 0.8612 - val_loss: 0.0446 - val_accuracy: 0.8610
# Epoch 49/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0444 - accuracy: 0.8612 - val_loss: 0.0448 - val_accuracy: 0.8609
# Epoch 50/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0444 - accuracy: 0.8612 - val_loss: 0.0448 - val_accuracy: 0.8625
# Epoch 51/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0444 - accuracy: 0.8612 - val_loss: 0.0446 - val_accuracy: 0.8613
# Epoch 52/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0443 - accuracy: 0.8612 - val_loss: 0.0448 - val_accuracy: 0.8609
# Epoch 53/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0443 - accuracy: 0.8612 - val_loss: 0.0447 - val_accuracy: 0.8614
# Epoch 54/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0442 - accuracy: 0.8611 - val_loss: 0.0444 - val_accuracy: 0.8615
# Epoch 55/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0440 - accuracy: 0.8611 - val_loss: 0.0443 - val_accuracy: 0.8605
# Epoch 56/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0440 - accuracy: 0.8611 - val_loss: 0.0443 - val_accuracy: 0.8612
# Epoch 57/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0440 - accuracy: 0.8610 - val_loss: 0.0444 - val_accuracy: 0.8609
# Epoch 58/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0438 - accuracy: 0.8611 - val_loss: 0.0445 - val_accuracy: 0.8604
# Epoch 59/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0437 - accuracy: 0.8610 - val_loss: 0.0440 - val_accuracy: 0.8613
# Epoch 60/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0437 - accuracy: 0.8608 - val_loss: 0.0442 - val_accuracy: 0.8627
# Epoch 61/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0437 - accuracy: 0.8610 - val_loss: 0.0442 - val_accuracy: 0.8598
# Epoch 62/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0436 - accuracy: 0.8608 - val_loss: 0.0439 - val_accuracy: 0.8596
# Epoch 63/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0435 - accuracy: 0.8608 - val_loss: 0.0440 - val_accuracy: 0.8612
# Epoch 64/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0434 - accuracy: 0.8607 - val_loss: 0.0439 - val_accuracy: 0.8612
# Epoch 65/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0433 - accuracy: 0.8607 - val_loss: 0.0440 - val_accuracy: 0.8602
# Epoch 66/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0434 - accuracy: 0.8606 - val_loss: 0.0437 - val_accuracy: 0.8606
# Epoch 67/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0432 - accuracy: 0.8605 - val_loss: 0.0444 - val_accuracy: 0.8603
# Epoch 68/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0431 - accuracy: 0.8604 - val_loss: 0.0437 - val_accuracy: 0.8605
# Epoch 69/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0430 - accuracy: 0.8604 - val_loss: 0.0435 - val_accuracy: 0.8595
# Epoch 70/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0428 - accuracy: 0.8602 - val_loss: 0.0437 - val_accuracy: 0.8604
# Epoch 71/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0429 - accuracy: 0.8602 - val_loss: 0.0434 - val_accuracy: 0.8601
# Epoch 72/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0426 - accuracy: 0.8602 - val_loss: 0.0434 - val_accuracy: 0.8592
# Epoch 73/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0425 - accuracy: 0.8601 - val_loss: 0.0433 - val_accuracy: 0.8593
# Epoch 74/200
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0424 - accuracy: 0.8599 - val_loss: 0.0432 - val_accuracy: 0.8596
# Epoch 75/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0422 - accuracy: 0.8599 - val_loss: 0.0432 - val_accuracy: 0.8588
# Epoch 76/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0421 - accuracy: 0.8598 - val_loss: 0.0431 - val_accuracy: 0.8600
# Epoch 77/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0419 - accuracy: 0.8597 - val_loss: 0.0430 - val_accuracy: 0.8598
# Epoch 78/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0418 - accuracy: 0.8598 - val_loss: 0.0432 - val_accuracy: 0.8585
# Epoch 79/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0417 - accuracy: 0.8596 - val_loss: 0.0428 - val_accuracy: 0.8591
# Epoch 80/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0414 - accuracy: 0.8595 - val_loss: 0.0428 - val_accuracy: 0.8584
# Epoch 81/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0413 - accuracy: 0.8595 - val_loss: 0.0427 - val_accuracy: 0.8592
# Epoch 82/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0412 - accuracy: 0.8594 - val_loss: 0.0430 - val_accuracy: 0.8587
# Epoch 83/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0409 - accuracy: 0.8594 - val_loss: 0.0425 - val_accuracy: 0.8587
# Epoch 84/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0408 - accuracy: 0.8594 - val_loss: 0.0425 - val_accuracy: 0.8571
# Epoch 85/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0406 - accuracy: 0.8593 - val_loss: 0.0423 - val_accuracy: 0.8585
# Epoch 86/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0405 - accuracy: 0.8592 - val_loss: 0.0423 - val_accuracy: 0.8577
# Epoch 87/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0404 - accuracy: 0.8592 - val_loss: 0.0422 - val_accuracy: 0.8577
# Epoch 88/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0403 - accuracy: 0.8591 - val_loss: 0.0421 - val_accuracy: 0.8574
# Epoch 89/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0401 - accuracy: 0.8591 - val_loss: 0.0421 - val_accuracy: 0.8578
# Epoch 90/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0400 - accuracy: 0.8590 - val_loss: 0.0421 - val_accuracy: 0.8576
# Epoch 91/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0400 - accuracy: 0.8591 - val_loss: 0.0422 - val_accuracy: 0.8569
# Epoch 92/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0397 - accuracy: 0.8590 - val_loss: 0.0420 - val_accuracy: 0.8576
# Epoch 93/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0397 - accuracy: 0.8590 - val_loss: 0.0421 - val_accuracy: 0.8576
# Epoch 94/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0395 - accuracy: 0.8590 - val_loss: 0.0421 - val_accuracy: 0.8573
# Epoch 95/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0394 - accuracy: 0.8589 - val_loss: 0.0422 - val_accuracy: 0.8571
# Epoch 96/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0393 - accuracy: 0.8590 - val_loss: 0.0422 - val_accuracy: 0.8575
# Epoch 97/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0393 - accuracy: 0.8590 - val_loss: 0.0422 - val_accuracy: 0.8567
# Epoch 98/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0391 - accuracy: 0.8591 - val_loss: 0.0421 - val_accuracy: 0.8560
# Epoch 99/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0389 - accuracy: 0.8590 - val_loss: 0.0421 - val_accuracy: 0.8566
# Epoch 100/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0388 - accuracy: 0.8590 - val_loss: 0.0422 - val_accuracy: 0.8560
# Epoch 101/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0388 - accuracy: 0.8591 - val_loss: 0.0421 - val_accuracy: 0.8562
# Epoch 102/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.
200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0217 - accuracy: 0.8669 - val_loss: 0.0556 - val_accuracy: 0.8436
# Epoch 194/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0216 - accuracy: 0.8669 - val_loss: 0.0560 - val_accuracy: 0.8431
# Epoch 195/200
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0215 - accuracy: 0.8670 - val_loss: 0.0559 - val_accuracy: 0.8437
# Epoch 196/200
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0214 - accuracy: 0.8671 - val_loss: 0.0560 - val_accuracy: 0.8433
# Epoch 197/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0213 - accuracy: 0.8671 - val_loss: 0.0563 - val_accuracy: 0.8431
# Epoch 198/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0212 - accuracy: 0.8672 - val_loss: 0.0563 - val_accuracy: 0.8433
# Epoch 199/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0211 - accuracy: 0.8673 - val_loss: 0.0564 - val_accuracy: 0.8433
# Epoch 200/200
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0209 - accuracy: 0.8674 - val_loss: 0.0567 - val_accuracy: 0.8432
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0564 - accuracy: 0.8431
# Test: 0.8430668711662292

# %%
def display_sample_prediction(n):
    labels = ['y_pred:', 'y_test:']
    for j, data in enumerate([pred, y_test]):
        plt.subplot(1,2,j+1)
        plt.axis('off')
        plt.title(labels[j])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    plt.show()

# Make predictions
pred = text2image_model2.predict(X_test)

# print images
print(pred.shape)

# data = [pred,y_test]
for i in range(20):
  display_sample_prediction(i)
# Out:
# 563/563 [==============================] - 2s 2ms/step
# (18000, 3, 28, 28, 1)

# %% [markdown]
# # Base model with Bidirectional LSTM

# %%
def build_text2image_model3():
    text2image = Sequential()

    # Encoder (for text sequences)
    text2image.add(Bidirectional(LSTM(256), input_shape=(None, len(unique_characters)))) # Bidirectional LSTM

    # Repeat the output for max_answer_length times
    text2image.add(RepeatVector(max_answer_length))

    # Decoder (for generating images)
    text2image.add(Bidirectional(LSTM(256, return_sequences=True)))
    text2image.add(TimeDistributed(Dense(128, activation='relu')))
    text2image.add(TimeDistributed(Dense(64, activation='relu')))  
    text2image.add(TimeDistributed(Dense(28 * 28, activation='sigmoid')))
    text2image.add(Reshape((max_answer_length, 28, 28, 1)))

    # Compile the model
    text2image.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

    text2image.summary()

    return text2image

# %%
# Compile the model
text2image_model3 = build_text2image_model3()

# Training the text-to-image model
text2image_model3.fit(
    X_text_train_onehot,
    y_img_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2
)

# Evaluating the model on the test set
test_loss, test_accuracy = text2image_model3.evaluate(
    X_text_test_onehot,
    y_img_test,
)
print(f"Test: {test_accuracy}")
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 512)               552960
#  al)
#
#  repeat_vector_21 (RepeatVe  (None, 3, 512)            0
#  ctor)
#
#  bidirectional_1 (Bidirecti  (None, 3, 512)            1574912
#  onal)
#
#  time_distributed_69 (TimeD  (None, 3, 128)            65664
#  istributed)
#
#  time_distributed_70 (TimeD  (None, 3, 64)             8256
#  istributed)
#
#  time_distributed_71 (TimeD  (None, 3, 784)            50960
#  istributed)
#
#  reshape_20 (Reshape)        (None, 3, 28, 28, 1)      0
#
# =================================================================
# Total params: 2252752 (8.59 MB)
# Trainable params: 2252752 (8.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 125/125 [==============================] - 9s 20ms/step - loss: 0.0833 - accuracy: 0.8412 - val_loss: 0.0553 - val_accuracy: 0.8644
# Epoch 2/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0546 - accuracy: 0.8652 - val_loss: 0.0548 - val_accuracy: 0.8642
# Epoch 3/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0541 - accuracy: 0.8648 - val_loss: 0.0543 - val_accuracy: 0.8652
# Epoch 4/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0531 - accuracy: 0.8645 - val_loss: 0.0526 - val_accuracy: 0.8647
# Epoch 5/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0505 - accuracy: 0.8646 - val_loss: 0.0502 - val_accuracy: 0.8638
# Epoch 6/200
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0492 - accuracy: 0.8649 - val_loss: 0.0490 - val_accuracy: 0.8638
# Epoch 7/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0485 - accuracy: 0.8646 - val_loss: 0.0489 - val_accuracy: 0.8650
# Epoch 8/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0482 - accuracy: 0.8644 - val_loss: 0.0484 - val_accuracy: 0.8636
# Epoch 9/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0478 - accuracy: 0.8640 - val_loss: 0.0483 - val_accuracy: 0.8631
# Epoch 10/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0477 - accuracy: 0.8640 - val_loss: 0.0476 - val_accuracy: 0.8626
# Epoch 11/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0475 - accuracy: 0.8637 - val_loss: 0.0476 - val_accuracy: 0.8642
# Epoch 12/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0471 - accuracy: 0.8633 - val_loss: 0.0471 - val_accuracy: 0.8643
# Epoch 13/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0470 - accuracy: 0.8633 - val_loss: 0.0472 - val_accuracy: 0.8627
# Epoch 14/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0468 - accuracy: 0.8630 - val_loss: 0.0473 - val_accuracy: 0.8630
# Epoch 15/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0467 - accuracy: 0.8629 - val_loss: 0.0468 - val_accuracy: 0.8634
# Epoch 16/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0466 - accuracy: 0.8629 - val_loss: 0.0467 - val_accuracy: 0.8631
# Epoch 17/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0464 - accuracy: 0.8626 - val_loss: 0.0469 - val_accuracy: 0.8638
# Epoch 18/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0463 - accuracy: 0.8626 - val_loss: 0.0465 - val_accuracy: 0.8625
# Epoch 19/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0461 - accuracy: 0.8625 - val_loss: 0.0464 - val_accuracy: 0.8615
# Epoch 20/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0459 - accuracy: 0.8622 - val_loss: 0.0466 - val_accuracy: 0.8632
# Epoch 21/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0460 - accuracy: 0.8622 - val_loss: 0.0459 - val_accuracy: 0.8615
# Epoch 22/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0458 - accuracy: 0.8620 - val_loss: 0.0461 - val_accuracy: 0.8633
# Epoch 23/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0456 - accuracy: 0.8621 - val_loss: 0.0460 - val_accuracy: 0.8607
# Epoch 24/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0457 - accuracy: 0.8620 - val_loss: 0.0459 - val_accuracy: 0.8621
# Epoch 25/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0454 - accuracy: 0.8620 - val_loss: 0.0458 - val_accuracy: 0.8622
# Epoch 26/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0452 - accuracy: 0.8616 - val_loss: 0.0457 - val_accuracy: 0.8611
# Epoch 27/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0450 - accuracy: 0.8616 - val_loss: 0.0455 - val_accuracy: 0.8607
# Epoch 28/200
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0450 - accuracy: 0.8614 - val_loss: 0.0459 - val_accuracy: 0.8612
# Epoch 29/200
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0451 - accuracy: 0.8616 - val_loss: 0.0460 - val_accuracy: 0.8604
# Epoch 30/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.
200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0169 - accuracy: 0.8694 - val_loss: 0.0580 - val_accuracy: 0.8438
# Epoch 182/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0170 - accuracy: 0.8694 - val_loss: 0.0579 - val_accuracy: 0.8433
# Epoch 183/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0168 - accuracy: 0.8695 - val_loss: 0.0582 - val_accuracy: 0.8435
# Epoch 184/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0167 - accuracy: 0.8696 - val_loss: 0.0581 - val_accuracy: 0.8437
# Epoch 185/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0167 - accuracy: 0.8696 - val_loss: 0.0581 - val_accuracy: 0.8439
# Epoch 186/200
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0166 - accuracy: 0.8696 - val_loss: 0.0582 - val_accuracy: 0.8434
# Epoch 187/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0165 - accuracy: 0.8697 - val_loss: 0.0584 - val_accuracy: 0.8432
# Epoch 188/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0164 - accuracy: 0.8698 - val_loss: 0.0582 - val_accuracy: 0.8435
# Epoch 189/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0163 - accuracy: 0.8698 - val_loss: 0.0584 - val_accuracy: 0.8435
# Epoch 190/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0163 - accuracy: 0.8698 - val_loss: 0.0585 - val_accuracy: 0.8437
# Epoch 191/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0163 - accuracy: 0.8698 - val_loss: 0.0586 - val_accuracy: 0.8433
# Epoch 192/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0162 - accuracy: 0.8698 - val_loss: 0.0585 - val_accuracy: 0.8434
# Epoch 193/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0161 - accuracy: 0.8699 - val_loss: 0.0588 - val_accuracy: 0.8431
# Epoch 194/200
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0160 - accuracy: 0.8699 - val_loss: 0.0588 - val_accuracy: 0.8431
# Epoch 195/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0159 - accuracy: 0.8700 - val_loss: 0.0587 - val_accuracy: 0.8435
# Epoch 196/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0159 - accuracy: 0.8700 - val_loss: 0.0588 - val_accuracy: 0.8434
# Epoch 197/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0158 - accuracy: 0.8700 - val_loss: 0.0588 - val_accuracy: 0.8434
# Epoch 198/200
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0158 - accuracy: 0.8701 - val_loss: 0.0589 - val_accuracy: 0.8438
# Epoch 199/200
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0158 - accuracy: 0.8701 - val_loss: 0.0592 - val_accuracy: 0.8434
# Epoch 200/200
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0158 - accuracy: 0.8700 - val_loss: 0.0592 - val_accuracy: 0.8434
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0590 - accuracy: 0.8440
# Test: 0.8439522385597229

# %%
def display_sample_prediction(n):
    labels = ['y_pred:', 'y_test:']
    for j, data in enumerate([pred, y_test]):
        plt.subplot(1,2,j+1)
        plt.axis('off')
        plt.title(labels[j])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    plt.show()

# Make predictions
pred = text2image_model3.predict(X_test)

# print images
print(pred.shape)


# data = [pred,y_test]
for i in range(20):
  display_sample_prediction(i)
# Out:
# 563/563 [==============================] - 3s 3ms/step
# (18000, 3, 28, 28, 1)

# %%
# Generating images with custom threshold

def generate_binary_images(model, input_sequence, threshold=0.4):
    predictions = model.predict(input_sequence)
    binary_predictions = (predictions > threshold).astype(np.uint8)
    return binary_predictions

def display_sample_prediction_with_threshold(n, threshold=0.5):
    labels = ['y_pred:', 'y_test:']
    for j, data in enumerate([generate_binary_images(text2image_model3, X_test, threshold), y_test]):
        plt.subplot(1,2,j+1)
        plt.axis('off')
        plt.title(labels[j])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    plt.show()


# Make predictions
pred = text2image_model3.predict(X_test)

# Print images
print(pred.shape)

# Make predictions with the binary thresholding
binary_pred = generate_binary_images(text2image_model3, X_test)

# Display sample predictions with the binary thresholding
for i in range(20):
    display_sample_prediction_with_threshold(i)
# Out:
# 563/563 [==============================] - 2s 4ms/step
# (18000, 3, 28, 28, 1)
# 563/563 [==============================] - 3s 6ms/step
# 563/563 [==============================] - 3s 5ms/step
# 563/563 [==============================] - 2s 3ms/step
# 563/563 [==============================] - 2s 3ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 3s 5ms/step
# 563/563 [==============================] - 3s 5ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 3ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 3s 5ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 2s 4ms/step
# 563/563 [==============================] - 3s 5ms/step

# %% [markdown]
# # Base model + Bidirectional LSTM + Regulazation (Dropout + BN)

# %%
def build_text2image_model4():
    text2image = Sequential()

    # Encoder (for text sequences)
    text2image.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2), input_shape=(None, len(unique_characters))))

    # Repeat the output for max_answer_length times
    text2image.add(RepeatVector(max_answer_length))

    # Decoder (for generating images)
    text2image.add(Bidirectional(LSTM(256, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)))
    text2image.add(TimeDistributed(Dense(128, activation='relu')))
    text2image.add(BatchNormalization())
    text2image.add(Dropout(0.2))
    text2image.add(TimeDistributed(Dense(64, activation='relu')))
    text2image.add(BatchNormalization())
    text2image.add(Dropout(0.2))
    text2image.add(TimeDistributed(Dense(28 * 28, activation='sigmoid')))
    text2image.add(Reshape((max_answer_length, 28, 28, 1)))

    # Compile the model
    text2image.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

    text2image.summary()

    return text2image

# %%
# Compile the model
text2image_model4 = build_text2image_model4()


# Training the text-to-image model
text2image_model4.fit(
    X_text_train_onehot,
    y_img_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2
)

# Evaluating the model on the test set
test_loss, test_accuracy = text2image_model4.evaluate(
    X_text_test_onehot,
    y_img_test,
)
print(f"Test: {test_accuracy}")
# Out:
# WARNING:tensorflow:Layer lstm_43 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_43 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_43 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# WARNING:tensorflow:Layer lstm_44 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_44 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_44 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirecti  (None, 512)               552960
#  onal)
#
#  repeat_vector_22 (RepeatVe  (None, 3, 512)            0
#  ctor)
#
#  bidirectional_3 (Bidirecti  (None, 3, 512)            1574912
#  onal)
#
#  time_distributed_72 (TimeD  (None, 3, 128)            65664
#  istributed)
#
#  batch_normalization_11 (Ba  (None, 3, 128)            512
#  tchNormalization)
#
#  dropout (Dropout)           (None, 3, 128)            0
#
#  time_distributed_73 (TimeD  (None, 3, 64)             8256
#  istributed)
#
#  batch_normalization_12 (Ba  (None, 3, 64)             256
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 64)             0
#
#  time_distributed_74 (TimeD  (None, 3, 784)            50960
#  istributed)
#
#  reshape_21 (Reshape)        (None, 3, 28, 28, 1)      0
#
# =================================================================
# Total params: 2253520 (8.60 MB)
# Trainable params: 2253136 (8.60 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1
200
# 125/125 [==============================] - 4s 31ms/step - loss: 0.0394 - accuracy: 0.8585 - val_loss: 0.0399 - val_accuracy: 0.8575
# Epoch 186/200
# 125/125 [==============================] - 5s 39ms/step - loss: 0.0395 - accuracy: 0.8584 - val_loss: 0.0397 - val_accuracy: 0.8581
# Epoch 187/200
# 125/125 [==============================] - 4s 36ms/step - loss: 0.0395 - accuracy: 0.8585 - val_loss: 0.0398 - val_accuracy: 0.8574
# Epoch 188/200
# 125/125 [==============================] - 4s 30ms/step - loss: 0.0394 - accuracy: 0.8586 - val_loss: 0.0397 - val_accuracy: 0.8580
# Epoch 189/200
# 125/125 [==============================] - 4s 30ms/step - loss: 0.0394 - accuracy: 0.8586 - val_loss: 0.0397 - val_accuracy: 0.8587
# Epoch 190/200
# 125/125 [==============================] - 5s 43ms/step - loss: 0.0393 - accuracy: 0.8586 - val_loss: 0.0398 - val_accuracy: 0.8572
# Epoch 191/200
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0393 - accuracy: 0.8585 - val_loss: 0.0397 - val_accuracy: 0.8576
# Epoch 192/200
# 125/125 [==============================] - 4s 30ms/step - loss: 0.0393 - accuracy: 0.8585 - val_loss: 0.0397 - val_accuracy: 0.8575
# Epoch 193/200
# 125/125 [==============================] - 4s 33ms/step - loss: 0.0393 - accuracy: 0.8585 - val_loss: 0.0398 - val_accuracy: 0.8573
# Epoch 194/200
# 125/125 [==============================] - 5s 43ms/step - loss: 0.0391 - accuracy: 0.8586 - val_loss: 0.0397 - val_accuracy: 0.8578
# Epoch 195/200
# 125/125 [==============================] - 4s 30ms/step - loss: 0.0392 - accuracy: 0.8585 - val_loss: 0.0397 - val_accuracy: 0.8576
# Epoch 196/200
# 125/125 [==============================] - 4s 30ms/step - loss: 0.0391 - accuracy: 0.8586 - val_loss: 0.0398 - val_accuracy: 0.8573
# Epoch 197/200
# 125/125 [==============================] - 5s 37ms/step - loss: 0.0391 - accuracy: 0.8585 - val_loss: 0.0396 - val_accuracy: 0.8576
# Epoch 198/200
# 125/125 [==============================] - 5s 38ms/step - loss: 0.0392 - accuracy: 0.8585 - val_loss: 0.0398 - val_accuracy: 0.8572
# Epoch 199/200
# 125/125 [==============================] - 4s 31ms/step - loss: 0.0391 - accuracy: 0.8586 - val_loss: 0.0399 - val_accuracy: 0.8580
# Epoch 200/200
# 125/125 [==============================] - 4s 31ms/step - loss: 0.0391 - accuracy: 0.8587 - val_loss: 0.0397 - val_accuracy: 0.8580
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0590 - accuracy: 0.8440
# Test: 0.8439522385597229

# %%
def display_sample_prediction(n):
    labels = ['y_pred:', 'y_test:']
    for j, data in enumerate([pred, y_test]):
        plt.subplot(1,2,j+1)
        plt.axis('off')
        plt.title(labels[j])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    plt.show()

# Make predictions
pred = text2image_model4.predict(X_test)

# print images
print(pred.shape)


# data = [pred,y_test]
for i in range(20):
  display_sample_prediction(i)
# Out:
# 563/563 [==============================] - 5s 7ms/step
# (18000, 3, 28, 28, 1)

# %%
# Creating images using custom threshold
def generate_binary_images(model, input_sequence, threshold=0.4):
    predictions = model.predict(input_sequence)
    binary_predictions = (predictions > threshold).astype(np.uint8)
    return binary_predictions

def display_sample_prediction_with_threshold(n, threshold=0.5):
    labels = ['y_pred:', 'y_test:']
    for j, data in enumerate([generate_binary_images(text2image_model4, X_test, threshold), y_test]):
        plt.subplot(1,2,j+1)
        plt.axis('off')
        plt.title(labels[j])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    plt.show()


# Making predictions
pred = text2image_model4.predict(X_test)
print(pred.shape)

# Make predictions with the binary thresholding
binary_pred = generate_binary_images(text2image_model4, X_test)

# Display sample predictions with the binary thresholding
for i in range(20):
    display_sample_prediction_with_threshold(i)
# Out:
# 563/563 [==============================] - 4s 7ms/step
# (18000, 3, 28, 28, 1)
# 563/563 [==============================] - 5s 9ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 5s 9ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 7s 13ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 6s 11ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 5s 8ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 5s 8ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 4s 8ms/step
# 563/563 [==============================] - 5s 8ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 5s 9ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 4s 7ms/step
# 563/563 [==============================] - 5s 9ms/step

# %% [markdown]
# # Adding additional LSTM layers to encoder

# %%
def build_text2image_model5():
    text2image = Sequential()

    # Encoder (for text sequences)
    text2image.add(Bidirectional(LSTM(256, return_sequences=True, dropout=0.2, recurrent_dropout=0.2), input_shape=(None, len(unique_characters))))
    text2image.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2))) # extra layer

    # Repeat the output for max_answer_length times
    text2image.add(RepeatVector(max_answer_length))

    # Decoder (for generating images)
    text2image.add(Bidirectional(LSTM(256, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)))
    text2image.add(TimeDistributed(Dense(128, activation='relu')))
    text2image.add(BatchNormalization())
    text2image.add(Dropout(0.2))
    text2image.add(TimeDistributed(Dense(64, activation='relu')))
    text2image.add(BatchNormalization())
    text2image.add(Dropout(0.2))
    text2image.add(TimeDistributed(Dense(28 * 28, activation='sigmoid')))
    text2image.add(Reshape((max_answer_length, 28, 28, 1)))

    # Compile the model
    text2image.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

    text2image.summary()

    return text2image

# %%
# Compile the model
text2image_model5 = build_text2image_model5()

# Training the text-to-image model
text2image_model5.fit(
    X_text_train_onehot,
    y_img_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2
)

# Evaluating the model on the test set
test_loss, test_accuracy = text2image_model5.evaluate(
    X_text_test_onehot,
    y_img_test,
)
print(f"Test: {test_accuracy}")
# Out:
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirect  (None, None, 512)         552960
#  ional)
#
#  bidirectional_13 (Bidirect  (None, 512)               1574912
#  ional)
#
#  repeat_vector_5 (RepeatVec  (None, 3, 512)            0
#  tor)
#
#  bidirectional_14 (Bidirect  (None, 3, 512)            1574912
#  ional)
#
#  time_distributed_14 (TimeD  (None, 3, 128)            65664
#  istributed)
#
#  batch_normalization (Batch  (None, 3, 128)            512
#  Normalization)
#
#  dropout (Dropout)           (None, 3, 128)            0
#
#  time_distributed_15 (TimeD  (None, 3, 64)             8256
#  istributed)
#
#  batch_normalization_1 (Bat  (None, 3, 64)             256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 64)             0
#
#  time_distributed_16 (TimeD  (None, 3, 784)            50960
#  istributed)
#
#  reshape_5 (Reshape)         (None, 3, 28, 28, 1)      0
#
# =================================================================
# Total params: 3828432 (14.60 MB)
# Trainable params: 3828048 (14.60 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/200
# 125/125 [==============================] - 28s 85ms/step - loss: 0.1696 - accuracy: 0.8394 - val_loss: 0.0771 - val_accuracy: 0.8665
# Epoch 2/200
# 125/125 [==============================] - 9s 71ms/step - loss: 0.0638 - accuracy: 0.8661 - val_loss: 0.0586 - val_accuracy: 0.8662
# Epoch 3/200
# 125/125 [==============================] - 9s 70ms/step - loss: 0.0582 - accuracy: 0.8660 - val_loss: 0.0572 - val_accuracy: 0.8665
# Epoch 4/200
# 125/125 [==============================] - 9s 72ms/step - loss: 0.0574 - accuracy: 0.8660 - val_loss: 0.0568 - val_accuracy: 0.8665
# Epoch 198/200
# 125/125 [==============================] - 8s 68ms/step - loss: 0.0404 - accuracy: 0.8588 - val_loss: 0.0401 - val_accuracy: 0.8584
# Epoch 199/200
# 125/125 [==============================] - 6s 49ms/step - loss: 0.0403 - accuracy: 0.8587 - val_loss: 0.0400 - val_accuracy: 0.8579
# Epoch 200/200
# 125/125 [==============================] - 8s 67ms/step - loss: 0.0404 - accuracy: 0.8587 - val_loss: 0.0398 - val_accuracy: 0.8589
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0399 - accuracy: 0.8586
# Test: 0.8586309552192688

# %%
def display_sample_prediction(n):
    labels = ['y_pred:', 'y_test:']
    for j, data in enumerate([pred, y_test]):
        plt.subplot(1,2,j+1)
        plt.axis('off')
        plt.title(labels[j])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    plt.show()
    
# Make predictions
pred = text2image_model5.predict(X_test)
print(pred.shape)

# Print 20 images
for i in range(20):
  display_sample_prediction(i)
# Out:
# 563/563 [==============================] - 6s 9ms/step
# (18000, 3, 28, 28, 1)

# %% [markdown]
# ---
# ---
# ---
#
# # Part 2: Multiplication
# The cell below will create the multiplication dataset used in this part of the assignment.

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789* '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 5    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer, operands=['*'])
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)


## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (10000,) (10000, 5, 28, 28) (10000,) (10000, 5, 28, 28)
# ==================================================
# Query #7675
#
# X_text: "76*75" = y_text: "5700 "
# ==================================================
# Query #9961
#
# X_text: "99*61" = y_text: "6039 "
# ==================================================
# Query #126
#
# X_text: "1*26 " = y_text: "26   "
# ==================================================
# Query #3702
#
# X_text: "37*2 " = y_text: "74   "
# ==================================================
# Query #7195
#
# X_text: "71*95" = y_text: "6745 "
# ==================================================
# Query #7931
#
# X_text: "79*31" = y_text: "2449 "
# ==================================================
# Query #2082
#
# X_text: "20*82" = y_text: "1640 "
# ==================================================
# Query #2933
#
# X_text: "29*33" = y_text: "957  "
# ==================================================
# Query #4652
#
# X_text: "46*52" = y_text: "2392 "
# ==================================================
# Query #3212
#
# X_text: "32*12" = y_text: "384  "

# %%
## Your code
